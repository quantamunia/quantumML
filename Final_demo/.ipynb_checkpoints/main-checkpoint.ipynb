# %%
#Rahul Matai, Neha, Muta, Aldridge Abaassa, Tinoda Garapasi

from flask import Flask, render_template, jsonify, Response,request, session, current_app,redirect, url_for,send_file, make_response, after_this_request
import tempfile
import numpy as np
import pandas as pd
import base64
import io 
import atexit
import os
import seaborn as sns
from IPython import get_ipython
import base64
import matplotlib.pyplot as plt
import random
import shutil

from flask_caching import Cache
from werkzeug.serving import WSGIRequestHandler
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn import decomposition
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score,confusion_matrix
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from IPython.display import clear_output

from qiskit.primitives import Sampler
from qiskit import Aer
from qiskit import transpile, execute
from qiskit.circuit.library import ZZFeatureMap, ZFeatureMap, PauliFeatureMap
from qiskit.circuit.library import RealAmplitudes
from qiskit.algorithms.optimizers import SPSA,COBYLA
from qiskit_machine_learning.algorithms import VQC
from qiskit_machine_learning.algorithms.classifiers import QSVC
from qiskit_machine_learning.kernels import QuantumKernel
from qiskit_machine_learning.exceptions import QiskitMachineLearningError
from qiskit.algorithms.state_fidelities import ComputeUncompute
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from azure.quantum import Workspace
from azure.quantum.qiskit import AzureQuantumProvider
from qiskit.visualization import circuit_drawer
from qiskit.visualization import plot_histogram

import time
import datetime


app = Flask(__name__)
app.config['SECRET_KEY'] = 'quantamunia'

app.config['SEND_FILE_MAX_AGE_DEFAULT'] = 0
class Calculations:
    def __init__(self):
        self.kernel_process = False
        self.vector_process = False
        self.var_circuit = None
        self.training_complete = False
        self.progress = 0
        self.imgkill = False
        self.tracker = False
        
    def model_track():
        self.tracker = True
        
    def model_end():
        self.tracker = False
        
    def vqc_begin(self,img_resetter):
        if img_resetter == "startp":
            self.vqc_proc = True
            
            
    def vqc_end(self,img_resetter):
        if img_resetter == "endp":
            self.vqc_proc = False
        
        
    def kernel_jobs(self, spinner):
        if spinner == "success":
            self.kernel_process = True
        elif spinner == "completed":
            self.vector_process = True
                
    def qsettings(self, var_circuit):
        # ... your training code ...
        self.var_circuit = var_circuit
        self.training_complete = True
        self.progress = 0
        
    def run_quantum_job(self):
        if self.var_circuit is not None:
            provider = AzureQuantumProvider(
                resource_id="/subscriptions/e7eef170-5f0d-42c3-a6c6-9ae33096de85/resourceGroups/AzureQuantum/providers/Microsoft.Quantum/Workspaces/Quantamunia",
                location="West Europe"
            )
            provider.backends()
            backend = provider.get_backend("ionq.simulator")
            params = self.var_circuit.parameters
            random_values = [random.uniform(0, 2 * np.pi) for _ in range(len(params))]
            bound_circuit = self.var_circuit.bind_parameters(dict(zip(params, random_values)))
            total_iterations = 10
            progress_values = []
            job = execute(bound_circuit, backend=backend)
            result = job.result()
            counts = result.get_counts()     
           
            fig = plot_histogram(counts)
            fig.text(0.5, 0.95, 'Circuit Histogram', ha='center', fontsize=12)
            
            
            
            temp_folder = os.path.join(app.static_folder,  temp_folder_name)
            os.makedirs(temp_folder, exist_ok=True)
            # Save the graph in the temporary folder
            graph_path = os.path.join(temp_folder, 'histogram.jpg')
            fig.savefig(graph_path)
            plt.close(fig)
            
              
         
        
        
        
        
        
            
                
            
            

spinObj = Calculations()
azureJob = Calculations()
vqcObj = Calculations()
imgCleaner = Calculations()



objective_func_vals = []
temp_folder_name = None

def delete_temp_folder():
    global temp_folder_name
    if temp_folder_name is not None:
        temp_folder_path = os.path.join(app.static_folder, temp_folder_name)
        if os.path.exists(temp_folder_path):
            shutil.rmtree(temp_folder_path)
    temp_folder_name = None  # Reset the temp_folder_name variable

def generate_temp_folder():
    global temp_folder_name
    if temp_folder_name is None:
        temp_folder_name = next(tempfile._get_candidate_names())
        
@app.before_request
def before_request():
    generate_temp_folder()
    

@app.route('/',methods=['GET', 'POST'])
def index():
    
   # session['temp_folder_name'] = temp_folder_name
   
    if request.method == 'POST':
        
        model = request.form['model']
        dataset = request.form['dataset']
        feature_map_type = request.form['featuremap']
        optimizer_type = request.form['optimizer']
        max_iter = request.form['max_iter']
        split = request.form['split']
        pca_no = request.form['pca']
        pca_no = int(pca_no)
        entang = request.form['entang']
       
      
        
        
        X,y,dset= load_dataset(dataset)
        
        feature_no = X.shape[1]
       
        X = pca(pca_no, X)
        
        test_size = split_ratio(split)
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)
        
        X_train_scaled, X_test_scaled = preprocess_data(X_train, X_test)
        
        
       
    
        feature_map, ansatz, base64_feature_map_image, base64_ansatz_image = create_feature_map(feature_map_type, pca_no, entang)
        
        optimizer, optname = create_optimizer(optimizer_type,max_iter)    
        
        import threading
        def train(model,optimizer,feature_map,ansatz,X_train_scaled, X_test_scaled, y_train, y_test,dset):
            
                load_model(model,optimizer,feature_map,ansatz,X_train_scaled, X_test_scaled, y_train, y_test,dset)
            
            
            
        train_thread = threading.Thread(target=train, args=(model,optimizer,feature_map,ansatz,X_train_scaled, X_test_scaled, y_train, y_test,dset))
        train_thread.start()
        
        return render_template('index.html',fmap=base64_feature_map_image, ans = base64_ansatz_image, dname = dataset, pcano=pca_no,
                               ent = entang, opt = optname, mod = model, f_no = pca_no)
    
    
       
          
       
    #return redirect(url_for('index'))
    return render_template('index.html')


    
def load_dataset(dataset):
    if dataset == 'iris':
        iris = datasets.load_iris()
        X = iris.data
        y = iris.target
        return X, y, iris
    if dataset == 'diabetes':
        diabetes = datasets.load_diabetes()
        X = diabetes.data
        y = diabetes.target
        return X, y,diabetes
    if dataset == 'wine':
        wine = datasets.load_wine()
        X = wine.data
        y = wine.target
        return X, y,wine
    if dataset == 'cancer':
        cancer = datasets.load_breast_cancer()
        X = cancer.data
        y = cancer.target
        return X, y,cancer
    
def split_ratio(split):
    if split == '80/20':
        return 0.2
    else :
        return 0.3

def preprocess_data(X_train, X_test):
    scaler = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    return X_train_scaled, X_test_scaled

def draw_and_encode_circuit(circuit):
    image_stream = io.BytesIO()
    circuit_drawer(circuit, output="mpl", fold=20, filename=image_stream)
    image_stream.seek(0)
    base64_image = base64.b64encode(image_stream.getvalue()).decode('utf-8')
    return base64_image

def create_feature_map(feature_map_type, fdimension, entang):
    if feature_map_type == 'zz':
        # Create the ZZFeatureMap and draw its circuit
        feature_map = ZZFeatureMap(feature_dimension=fdimension, reps=2, entanglement=entang)
        base64_feature_map_image = draw_and_encode_circuit(feature_map.decompose())

        # Create the RealAmplitudes ansatz and draw its circuit
        ansatz = RealAmplitudes(num_qubits=fdimension, reps=3)
        base64_ansatz_image = draw_and_encode_circuit(ansatz.decompose())

        return feature_map,ansatz, base64_feature_map_image, base64_ansatz_image
    
    elif feature_map_type == 'z':
        # Create the ZFeatureMap and draw its circuit
        feature_map = ZFeatureMap(feature_dimension=fdimension, reps=1)
        base64_feature_map_image = draw_and_encode_circuit(feature_map.decompose())

        # Create the RealAmplitudes ansatz and draw its circuit
        ansatz = RealAmplitudes(num_qubits=fdimension, reps=3)
        base64_ansatz_image = draw_and_encode_circuit(ansatz.decompose())

        return feature_map,ansatz,base64_feature_map_image, base64_ansatz_image
    
    elif feature_map_type == 'pauli':
        # Create the ZZFeatureMap and draw its circuit
        feature_map = PauliFeatureMap(feature_dimension=fdimension, reps=1, entanglement=entang)
        base64_feature_map_image = draw_and_encode_circuit(feature_map.decompose())

        # Create the RealAmplitudes ansatz and draw its circuit
        ansatz = RealAmplitudes(num_qubits=fdimension, reps=3)
        base64_ansatz_image = draw_and_encode_circuit(ansatz.decompose())

        return feature_map,ansatz,base64_feature_map_image, base64_ansatz_image

def create_optimizer(optimizer_type,max_iter):
    if optimizer_type == 'spsa':
        return SPSA(maxiter=max_iter), "SPSA"
    elif optimizer_type == 'cobyla':
        return COBYLA(maxiter=max_iter), "COBYLA"
    elif optimizer_type == 'adam':
        return COBYLA(maxiter=max_iter), "ADAM"
    else:
        return "NONE", "NONE"
    
def pca(pca_no,X):
    pca = decomposition.PCA(n_components=pca_no)
    pca.fit(X)
    X = pca.transform(X)
    return X   
    
    
     
#model,optimizer,feature_map,ansatz, X_train_scaled, X_test_scaled, y_train, y_test

def load_model(model,optimizer,feature_map,ansatz,X_train_scaled, X_test_scaled, y_train, y_test,dset):
   
    if model == "VQC/MLP":
        imgCleaner.imgkill = True
        c_metrics = mlp_classifier(X_train_scaled, X_test_scaled, y_train, y_test,dset)
        q_metrics = vqc_classifier(optimizer,feature_map,ansatz, X_train_scaled, X_test_scaled, y_train, y_test,dset)        
        barchart_mlp_vqc(model,c_metrics,q_metrics)
        
    
    if model == "QSVM/SVM":
        imgCleaner.imgkill = True
        c_metrics = svm_classifier(X_train_scaled, X_test_scaled, y_train, y_test,dset)
        q_metrics = qsvm_classifier(feature_map,X_train_scaled, X_test_scaled, y_train, y_test,dset)
        barchart_mlp_vqc(model,c_metrics,q_metrics)
        
    
    if model == "QSVC/SVC":
        imgCleaner.imgkill = True
        c_metrics = svc_classifier(X_train_scaled, X_test_scaled, y_train, y_test,dset)
        q_metrics = qsvc_classifier(feature_map,X_train_scaled, X_test_scaled, y_train, y_test,dset)
        barchart_mlp_vqc(model,c_metrics,q_metrics)
    
    if model == "VQC/LR":
        imgCleaner.imgkill = True
        c_metrics = lr_classifier(X_train_scaled, X_test_scaled, y_train, y_test,dset)
        q_metrics = vqc_classifier(optimizer,feature_map,ansatz,X_train_scaled, X_test_scaled, y_train, y_test,dset)
        barchart_mlp_vqc(model,c_metrics,q_metrics)

#=============================== MLP / VQC CLASSIFIER==========================


def mlp_classifier(X_train_scaled, X_test_scaled, y_train, y_test,dset):
    
    # Create an instance of the MLP classifier
    mlp = MLPClassifier(hidden_layer_sizes=(50,), max_iter=4000, random_state=42)
    # Train the MLP classifier
    mlp.fit(X_train_scaled, y_train)
    # Make predictions with MLP classifier
    y_pred_mlp = mlp.predict(X_test_scaled)
    # Calculate accuracy, F1 score, precision, and recall for MLP classifier
    cm = confusion_matrix(y_test, y_pred_mlp)
    accuracy_mlp = accuracy_score(y_test, y_pred_mlp)
    f1_mlp = f1_score(y_test, y_pred_mlp, average='weighted')
    precision_mlp = precision_score(y_test, y_pred_mlp, average='weighted')
    recall_mlp = recall_score(y_test, y_pred_mlp, average='weighted') 
    class_name = "MLP"
    imgCleaner.imgkill = False
    plot_confusion_matrix(cm, title=f'Confusion Matrix for {class_name}', classes=dset.target_names, filename='cc_matrix.jpg')
    print(accuracy_mlp)
    print(precision_mlp)
    print(recall_mlp)
    print(f1_mlp)
    return accuracy_mlp, f1_mlp, precision_mlp, recall_mlp


def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration", fontweight="bold", fontsize=13, y=1.05)
    plt.xlabel("Iteration", fontsize=12)
    plt.ylabel("Objective function value",fontsize=12)
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    # Generate a timestamp
    #timestamp = datetime.datetime.now().strftime('%Y%m%d%H%M%S')

    # Append the timestamp to the filename
    #filename = f'static/graph_{timestamp}.jpg'
    #plt.savefig('static/graph.jpg')  # Save the graph as an image
    #plt.close()
    # Generate a random name for the temporary folder
    # Retrieve the temporary folder name from the session
    # Create the temporary folder inside the static folder
    temp_folder = os.path.join(app.static_folder,  temp_folder_name)
    os.makedirs(temp_folder, exist_ok=True)
    # Save the graph in the temporary folder
    graph_path = os.path.join(temp_folder, 'graph.jpg')
    
    
    
    
    
    
    
    
    
    plt.savefig(graph_path)  # Save the graph as an image
    plt.close()
    return graph_path
    
#def tooo():
    #print('hello')

def vqc_classifier(optimizer,feature_map,ansatz, X_train_scaled, X_test_scaled, y_train, y_test,dset):
    objective_func_vals.clear()
   
    #vqcObj.vqc_begin("startp")
    sampler = Sampler()
    vqc = VQC(
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=optimizer,
    callback=callback_graph,

    )
   
    #import threading
    #def run_callback():
    vqc.fit(X_train_scaled, y_train)

    #train_thread = threading.Thread(target=run_callback)
    #train_thread.start()
    
    # Wait for the training thread to finish
    #train_thread.join()

    
    # Make predictions with VQC
    y_pred_vqc = vqc.predict(X_test_scaled)
    # Calculate accuracy, F1 score, precision, and recall for VQC
    cm = confusion_matrix(y_test, y_pred_vqc)
    accuracy_vqc = accuracy_score(y_test, y_pred_vqc)
    f1_vqc = f1_score(y_test, y_pred_vqc, average='weighted')
    precision_vqc = precision_score(y_test, y_pred_vqc, average='weighted')
    recall_vqc = recall_score(y_test, y_pred_vqc, average='weighted')
    print(accuracy_vqc)
    print(f1_vqc)
    print(precision_vqc)
    print( recall_vqc)
    spinner = "completed"
    spinObj.kernel_jobs(spinner)
    class_name = "VQC"
    plot_confusion_matrix(cm, title=f'Confusion Matrix for {class_name}', classes=dset.target_names, filename='qc_matrix.jpg')
    #vqcObj.vqc_end("endp")
    azureJob.qsettings(vqc.circuit)
    return accuracy_vqc ,f1_vqc,precision_vqc, recall_vqc

def barchart_mlp_vqc(model, c_metrics, q_metrics):
    metrics = {}
    quantum, classical = model.split('/')
    # Bar chart
    metrics['c'] = c_metrics
    metrics['q'] = q_metrics
    accuracy_c, f1_c, precision_c, recall_c = metrics['c']
    accuracy_q, f1_q, precision_q, recall_q = metrics['q']
    accuracy_c = round(accuracy_c,2)
    f1_c=round(f1_c,2)
    precision_c=round(precision_c,2)
    recall_c=round(recall_c,2)
    accuracy_q = round(accuracy_q,2)
    f1_q=round(f1_q,2)
    precision_q=round(precision_q,2)
    recall_q=round(recall_q,2)
    labels = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
    c_scores = [accuracy_c, precision_c, recall_c, f1_c]
    q_scores = [accuracy_q, precision_q, recall_q, f1_q]

    x = np.arange(len(labels))
    width = 0.35

    fig, ax = plt.subplots()
    rects1 = ax.bar(x - width/2, c_scores, width, label=classical)
    rects2 = ax.bar(x + width/2, q_scores, width, label=quantum)
    ax.margins(y=0.15)
    ax.set_ylabel('Scores')
    ax.set_title(f'Comparison of Metrics: {classical} vs {quantum}', pad=20)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend(bbox_to_anchor=(1, 1))

    ax.bar_label(rects1, padding=3)
    ax.bar_label(rects2, padding=3)

    fig.tight_layout()
    
    
    
    temp_folder = os.path.join(app.static_folder,  temp_folder_name)
    os.makedirs(temp_folder, exist_ok=True)
    # Save the graph in the temporary folder
    graph_path = os.path.join(temp_folder, 'barchart.jpg')
    # Save the plot as a JPG image in the static folder
    
    
    
    #plt.savefig('static/barchart.jpg')
    plt.savefig(graph_path)
    # Close the plot to free up resources
    plt.close()
  
    


 



#================================= QSVM/SVM======================================================

def svm_classifier(X_train_scaled, X_test_scaled, y_train, y_test,dset):
    
    svm = SVC(kernel='linear')
    svm.fit(X_train_scaled, y_train)
    svm_pred = svm.predict(X_test_scaled)
    
    
  
    cm = confusion_matrix(y_test, svm_pred)
    svm_accuracy = accuracy_score(y_test, svm_pred)
    svm_precision = precision_score(y_test, svm_pred, average='macro')
    svm_recall = recall_score(y_test, svm_pred, average='macro')
    svm_f1 = f1_score(y_test, svm_pred, average='macro')
    print(svm_accuracy)
    print(svm_f1)
    print(svm_precision)
    print( svm_recall)
    class_name = "SVM"
    imgCleaner.imgkill = False
    plot_confusion_matrix(cm, title=f'Confusion Matrix for {class_name}', classes=dset.target_names, filename="cc_matrix.jpg")
    return svm_accuracy,svm_precision, svm_recall,svm_f1
    
    
def qsvm_classifier(feature_map, X_train_scaled, X_test_scaled, y_train, y_test,dset):
   
    qkernel = QuantumKernel(feature_map=feature_map, quantum_instance=Aer.get_backend('qasm_simulator'))
    qsvm = QSVC(quantum_kernel=qkernel)
    #start = time.time()
    #epochs = 4
    #for _ in tqdm(range(epochs), desc="Training Progress"):
    qsvm.fit(X_train_scaled, y_train)
    #elapsed = time.time() - start
    # Predict labels for the test set
    y_pred = qsvm.predict(X_test_scaled)
    cm = confusion_matrix(y_test, y_pred)
   
    qsvm_accuracy = np.sum(y_pred == y_test) / len(y_test)
    qsvm_f1 = f1_score(y_test, y_pred, average='weighted')
    qsvm_precision = precision_score(y_test, y_pred, average='weighted')
    qsvm_recall = recall_score(y_test, y_pred, average='weighted')
    print(qsvm_accuracy)
    print(qsvm_f1)
    print(qsvm_precision)
    print( qsvm_recall)
    spinner = "success"
    spinObj.kernel_jobs(spinner)
    class_name = "QSVM"
    plot_confusion_matrix(cm, title=f'Confusion Matrix for {class_name}', classes=dset.target_names, filename="qc_matrix.jpg")
    return qsvm_accuracy,qsvm_f1,qsvm_precision,qsvm_recall
  

#================================QSVC/SVC======================================================

def svc_classifier(X_train_scaled, X_test_scaled, y_train, y_test,dset):
    svc = SVC()
    svc.fit(X_train_scaled, y_train) 
    svc_pred = svc.predict(X_test_scaled)
    
    cm = confusion_matrix(y_test, svc_pred)
    svc_accuracy = accuracy_score(y_test, svc_pred)
    svc_precision = precision_score(y_test, svc_pred, average='macro')
    svc_recall = recall_score(y_test, svc_pred, average='macro')
    svc_f1 = f1_score(y_test, svc_pred, average='macro')
    imgCleaner.imgkill = False
    class_name = "SVC"
    plot_confusion_matrix(cm, title=f'Confusion Matrix for {class_name}', classes=dset.target_names, filename="cc_matrix.jpg")
    return svc_accuracy,svc_precision, svc_recall,svc_f1

def qsvc_classifier(feature_map, X_train_scaled, X_test_scaled, y_train, y_test,dset):
    
    sampler = Sampler()
    fidelity = ComputeUncompute(sampler=sampler)
    kernel = FidelityQuantumKernel(fidelity=fidelity, feature_map=feature_map)
    qsvc = QSVC(quantum_kernel=kernel)
    #start = time.time()
    qsvc.fit(X_train_scaled, y_train)
    #elapsed = time.time() - start
    y_pred = qsvc.predict(X_test_scaled)
    cm = confusion_matrix(y_test, y_pred)
    qsvc_accuracy = np.sum(y_pred == y_test) / len(y_test)
    qsvc_f1 = f1_score(y_test, y_pred, average='weighted')
    qsvc_precision = precision_score(y_test, y_pred, average='weighted')
    qsvc_recall = recall_score(y_test, y_pred, average='weighted')  
    spinner = "success"
    spinObj.kernel_jobs(spinner)
    class_name = "QSVC"
    plot_confusion_matrix(cm, title=f'Confusion Matrix for {class_name}', classes=dset.target_names, filename="qc_matrix.jpg")
    return qsvc_accuracy,qsvc_f1,qsvc_precision,qsvc_recall


#================================VQC/LR======================================================


    
def lr_classifier(X_train_scaled, X_test_scaled, y_train, y_test,dset):
    # Create a logistic regression CL_model_LR
    lr = LogisticRegression()
    # Train the CL_model_LR
    lr.fit(X_train_scaled,  y_train)
    # Make predictions on the test set
    y_pred = lr.predict(X_test_scaled)
    cm = confusion_matrix(y_test, y_pred)
    lr_accuracy = accuracy_score(y_test, y_pred)
    lr_precision = precision_score(y_test, y_pred, average='macro')
    lr_recall = recall_score(y_test, y_pred, average='macro')
    lr_f1 = f1_score(y_test, y_pred, average='macro')
    class_name = "LR"
    imgCleaner.imgkill = False
    plot_confusion_matrix(cm, title=f'Confusion Matrix for {class_name}', classes=dset.target_names, filename="cc_matrix.jpg")
    return lr_accuracy,lr_precision, lr_recall,lr_f1



# Create a function to display the confusion matrix in a smaller size
def plot_confusion_matrix(cm, title, classes, filename):
  
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.tight_layout()
    
    temp_folder = os.path.join(app.static_folder,  temp_folder_name)
    os.makedirs(temp_folder, exist_ok=True)
    # Save the graph in the temporary folder
    graph_path = os.path.join(temp_folder, filename)
    # Save the plot as a JPG image in the static folder
    
    
    plt.savefig(graph_path)
    plt.close()


    


def ansatz_cir(N):
    image_stream = io.BytesIO()
    ansatz = RealAmplitudes(num_qubits=N, reps=3)
    ansatz.decompose().draw(output="mpl", fold=20,filename=image_stream )
    image_stream.seek(0)
    base64_image = base64.b64encode(image_stream.getvalue()).decode('utf-8')
    return base64_image

    
#@app.route('/get_graph_data')

#def get_graph_data():   
    # Return the current timestamp as a unique parameter to prevent caching
    #timestamp = int(time.time() * 1000)
    #return jsonify({'graph_src': f'static/temp/graph.jpg?{timestamp}'})

#@app.route('/get_graph_data')
#def get_graph_data():
    #timestamp = int(time.time() * 1000)
    #graph_path = callback_graph()
    #return jsonify({'graph_src': graph_path})
    
    
@app.route('/get_graph_data')
def get_graph_data():
    #temp_folder_name = session.get('temp_folder_name')
    # Construct the path to the graph image
    graph_path = os.path.join('static', temp_folder_name, 'graph.jpg')
   
    timestamp = int(time.time() * 1000)
    # Return the graph image path as JSON
    return jsonify({'graph_src': f"{graph_path}?{timestamp}"})






@app.route('/get_barchart')
def get_barchart():
    #temp_folder_name = session.get('temp_folder_name')
     # Construct the path to the graph image
    graph_path = os.path.join('static', temp_folder_name, 'barchart.jpg')
    # Return the current timestamp as a unique parameter to prevent caching
    timestamp = int(time.time() * 1500)
    #return jsonify({'bar_src': f'static/barchart.jpg?{timestamp}'})
    return jsonify({'bar_src': f"{graph_path}?{timestamp}"})

@app.route('/get_cc_matrix')
def get_cc_matrix():
    #temp_folder_name = session.get('temp_folder_name')
    # Construct the path to the graph image
    graph_path = os.path.join('static', temp_folder_name, 'cc_matrix.jpg')
    # Return the current timestamp as a unique parameter to prevent caching
    timestamp = int(time.time() * 2000)
    #return jsonify({'bar_src': f'static/cc_matrix.jpg?{timestamp}'})
    return jsonify({'bar_src': f"{graph_path}?{timestamp}"})

@app.route('/get_qc_matrix')
def get_qc_matrix():
    #temp_folder_name = session.get('temp_folder_name')
    # Construct the path to the graph image
    graph_path = os.path.join('static', temp_folder_name, 'qc_matrix.jpg')
    # Return the current timestamp as a unique parameter to prevent caching
    timestamp = int(time.time() * 2500)
    #return jsonify({'bar_src': f'static/qc_matrix.jpg?{timestamp}'})
    return jsonify({'bar_src': f"{graph_path}?{timestamp}"})

@app.route('/quantum_job')
def quantum_job_route():
    if azureJob.training_complete:
        
        azureJob.run_quantum_job()
        azureJob.training_complete = False
        
       
        return jsonify({'result': 'success', 'progress': 0})
    else:
        return jsonify({'result': 'training_in_progress', 'progress': azureJob.progress})


@app.route('/get_hist')
def get_hist():
    #temp_folder_name = session.get('temp_folder_name')
    # Construct the path to the graph image
    graph_path = os.path.join('static', temp_folder_name, 'histogram.jpg')
     # Return the current timestamp as a unique parameter to prevent caching
    timestamp = int(time.time() * 4000)
    #return jsonify({'hist_src': f'static/histogram.jpg?{timestamp}'})
    return jsonify({'hist_src': f"{graph_path}?{timestamp}"})

@app.route('/q_spinner')
def q_spinner():
    if spinObj.vector_process:
        qvector =  "completed"
        spinObj.vector_process = False
        return jsonify({"spinner": qvector})
    
    if spinObj.kernel_process:
        spinner = "success"
        spinObj.kernel_process = False
        return jsonify({"spinner": spinner})
    else:
        spinner = "training"
        return jsonify({"spinner": spinner})
    


            

@app.route('/img_kill')   
def img_kill():
    
    if imgCleaner.imgkill == True:
        
        @after_this_request
        def add_cache_control(response):
            response.headers['Cache-Control'] = 'no-store, no-cache, must-revalidate, max-age=0'
            response.headers['Pragma'] = 'no-cache'
            response.headers['Expires'] = '0'
            return response
        
        static_folder = os.path.join('static', temp_folder_name)
        extensions_to_delete = ['.jpg', '.png']
        for filename in os.listdir(static_folder):
            if any(filename.lower().endswith(ext) for ext in extensions_to_delete):
                file_path = os.path.join(static_folder, filename)
                os.remove(file_path)
        #redirect(url_for('index.html'))
        
        return jsonify({'message': 'deleted'})
    else:
        return jsonify({'message': 'not deleting'})
        
    
     
    
    
  

if __name__ == '__main__':
   
    #atexit.register(img_kill)
    app.run(port=5889, debug=False, use_reloader=False)
# Out:
# 127.0.0.1 - - [14/Aug/2023 16:02:25] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:25] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050690321 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:25] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063363338 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:25] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:25] "GET /static/ap9ogwxs/barchart.jpg?2538038018052 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050690904 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063363862 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "
# 0.8333333333333334
# 0.8269394714407502
# 0.8928571428571428
# 0.8333333333333334
# GET /static/ap9ogwxs/barchart.jpg?2538038018383 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063366426 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:26] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050693078 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /static/ap9ogwxs/barchart.jpg?2538038020028 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050693688 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063367310 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /static/ap9ogwxs/barchart.jpg?2538038020560 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050694275 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063367976 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:27] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050694727 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/barchart.jpg?2538038020877 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063368845 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050695211 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/barchart.jpg?2538038022182 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063370427 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050696433 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063370800 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/barchart.jpg?2538038022375 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050696670 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/barchart.jpg?2538038022656 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063370988 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050696978 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063371423 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:28] "GET /static/ap9ogwxs/barchart.jpg?2538038022785 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050697230 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063372301 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/barchart.jpg?2538038023457 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050698055 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063372779 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/barchart.jpg?2538038023756 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050698423 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063373151 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/barchart.jpg?2538038023979 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050698714 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063373483 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/barchart.jpg?2538038024154 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /q_spinner HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /img_kill HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_hist HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_hist HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_graph_data HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050698996 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063373834 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:29] "GET /static/ap9ogwxs/barchart.jpg?2538038024542 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/histogram.jpg?6768101399090 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/histogram.jpg?6768101399194 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/graph.jpg?1692025349818 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050699669 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063374711 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/barchart.jpg?2538038024875 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050700121 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063375673 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/barchart.jpg?2538038025523 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050700975 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063376299 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/barchart.jpg?2538038025829 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050701172 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063376544 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/barchart.jpg?2538038025967 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050701335 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063376732 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/barchart.jpg?2538038026087 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050701527 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063376993 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:30] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038026246 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050701854 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063377376 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038026472 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050702053 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063377634 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038026607 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050702203 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063377821 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038026744 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050702351 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063378018 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038026831 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050702513 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038026982 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063378237 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050702707 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063378510 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038027069 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050702834 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038027495 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063378963 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050703367 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038027547 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063379359 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050703536 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:31] "GET /static/ap9ogwxs/barchart.jpg?2538038027849 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050703903 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063379799 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/barchart.jpg?2538038027966 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050704006 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063380071 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/barchart.jpg?2538038028129 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050704242 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063380379 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/barchart.jpg?2538038028315 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050704666 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063381002 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050704957 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/barchart.jpg?2538038028669 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063381290 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/barchart.jpg?2538038028847 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /img_kill HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_hist HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_hist HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050705055 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063381479 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050705392 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/barchart.jpg?2538038028947 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/histogram.jpg?6768101410716 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/histogram.jpg?6768101410743 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063381834 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/barchart.jpg?2538038029204 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050705560 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:32] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063382138 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050705901 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038029324 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063382466 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038029577 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050706040 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063382701 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038029630 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050706253 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063382900 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038029780 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063383078 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050706403 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038029892 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063383183 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050706599 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038030173 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063383753 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050707101 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038030372 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063384119 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050707336 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038030529 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063384281 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050707495 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038030655 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063384523 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050707660 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/barchart.jpg?2538038030776 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:33] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063384789 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050707889 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063384972 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038030949 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050708026 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031082 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063385054 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050708129 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063385280 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031149 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050708247 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063385407 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031270 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050708426 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063385594 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031395 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050708572 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063385791 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031499 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050708694 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063385885 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031554 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050708761 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063386002 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031680 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063386280 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050708949 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031781 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_graph_data HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063386397 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050709161 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038031902 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/graph.jpg?1692025354630 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063386591 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050709299 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038032022 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063386857 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050709561 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063387183 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/barchart.jpg?2538038032277 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050709820 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:34] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063387293 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038032416 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050709927 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063387481 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710095 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038032527 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063387676 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038032645 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710163 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063387831 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710363 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038032722 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063388016 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038032873 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710469 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063388163 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710569 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038032943 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063388285 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710671 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033046 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063388458 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710797 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033121 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710909 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063388617 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033227 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050710990 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063388812 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033311 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050711133 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063388950 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033385 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050711197 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063389052 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033503 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050711395 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063389343 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033626 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050711604 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033768 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063389571 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050711741 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063389804 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:35] "GET /static/ap9ogwxs/barchart.jpg?2538038033848 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050711892 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038033957 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063389902 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050712023 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063390088 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038034029 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050712160 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038034202 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063390269 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050712300 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063390577 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038034290 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050712480 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063390692 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038034427 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050712601 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063390950 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038034581 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050712830 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063391088 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038034697 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063391383 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050712955 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038034851 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050713213 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063391488 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038034950 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063391650 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050713297 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038035003 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063391770 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038035094 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050713427 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063391884 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038035198 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050713616 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063392063 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038035290 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050713734 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063392254 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /static/ap9ogwxs/barchart.jpg?2538038035378 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:36] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:37] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063392385 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:37] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:37] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:02:37] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050713891 HTTP/1.1" 200 -
# ...
# 127.0.0.1 - - [14/Aug/2023 16:04:40] "GET /img_kill HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038221377 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063702318 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050961880 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038221511 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063702561 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050962110 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038221603 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050962277 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063702787 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038221750 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063702963 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050962386 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038221834 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063703106 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050962520 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_hist HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038221921 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063703251 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_hist HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050962628 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/histogram.jpg?6768101925352 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038222030 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063703466 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050962885 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/histogram.jpg?6768101925818 HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038222227 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063703764 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050963038 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038222377 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063704046 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050963295 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038222501 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063704230 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050963437 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038222650 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063704425 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050963617 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /static/ap9ogwxs/barchart.jpg?2538038222760 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:41] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063704651 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050963773 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038222947 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063704980 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050964033 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038223055 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063705147 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050964153 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038223156 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063705321 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050964296 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038223261 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063705503 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050964471 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038223399 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063705728 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050964646 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038223551 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063705976 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050964836 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038223678 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063706214 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050965042 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038223832 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050965220 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063706452 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038223935 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063706664 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050965292 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038224022 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050965426 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063706742 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/barchart.jpg?2538038224085 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:42] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063707248 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050965750 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/barchart.jpg?2538038224386 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050966017 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063707357 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/barchart.jpg?2538038224558 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050966119 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063707734 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/barchart.jpg?2538038224677 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050966296 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063707906 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/barchart.jpg?2538038224818 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:43] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050967664 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063709697 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050967947 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /static/ap9ogwxs/barchart.jpg?2538038225924 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063710003 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /static/ap9ogwxs/barchart.jpg?2538038226065 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_cc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /static/ap9ogwxs/cc_matrix.jpg?3384050968035 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_qc_matrix HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_barchart HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /static/ap9ogwxs/qc_matrix.jpg?4230063710149 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /static/ap9ogwxs/barchart.jpg?2538038226150 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 16:04:44] "GET /get_cc_matrix HTTP/1.1" 200 -
