# %%
pip install qiskit
pip install pylatexenc

# %%
from sklearn.datasets import load_iris

iris_data = load_iris()

# %%
features = iris_data.data
labels = iris_data.target

# %%
features.shape
# Out:
# (150, 4)

# %%
from sklearn.preprocessing import MinMaxScaler

features = MinMaxScaler().fit_transform(features)

# %%
from sklearn.model_selection import train_test_split
from qiskit.utils import algorithm_globals

algorithm_globals.random_seed = 123
train_features, test_features, train_labels, test_labels = train_test_split(
    features, labels, train_size=0.8, random_state=algorithm_globals.random_seed
)

# %%
from sklearn.svm import SVC

svc = SVC()
_ = svc.fit(train_features, train_labels)  # suppress printing the return value

# %%
train_score_c4 = svc.score(train_features, train_labels)
test_score_c4 = svc.score(test_features, test_labels)

print(f"Classical SVC on the training dataset: {train_score_c4:.2f}")
print(f"Classical SVC on the test dataset:     {test_score_c4:.2f}")
# Out:
# Classical SVC on the training dataset: 0.99
# Classical SVC on the test dataset:     0.97

# %%
from qiskit.circuit.library import ZZFeatureMap

num_features = features.shape[1]

feature_map = ZZFeatureMap(feature_dimension=num_features, reps=1)
feature_map.decompose().draw(output="mpl", fold=40)

# %%
from qiskit.circuit.library import RealAmplitudes

ansatz = RealAmplitudes(num_qubits=num_features, reps=3)
ansatz.decompose().draw(output="mpl", fold=20)

# %%
from qiskit.algorithms.optimizers import COBYLA

optimizer = COBYLA(maxiter=100)

# %%
from qiskit.primitives import Sampler

sampler = Sampler()

# %%
from matplotlib import pyplot as plt
from IPython.display import clear_output

objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)


def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

# %%
pip install qiskit-machine-learning
# Out:
# Collecting qiskit-machine-learning
#   Downloading qiskit_machine_learning-0.6.1-py3-none-any.whl (148 kB)
# Requirement already satisfied: psutil>=5 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-machine-learning) (5.8.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-machine-learning) (1.0.2)
# Collecting fastdtw
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-machine-learning) (1.21.5)
# Requirement already satisfied: dill>=0.3.4 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-machine-learning) (0.3.6)
# Requirement already satisfied: scipy>=1.4 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-machine-learning) (1.7.3)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-machine-learning) (61.2.0)
# Requirement already satisfied: qiskit-terra>=0.22.2 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-machine-learning) (0.24.1)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (5.1.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (1.10.1)
# Requirement already satisfied: ply>=3.10 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (3.11)
# Requirement already satisfied: rustworkx>=0.12.0 in c:\users\neha\anaconda3\lib\site-packages (from qiskit-terra>=0.22.2->qiskit-machine-learning) (0.13.0)
# Requirement already satisfied: six>=1.5 in c:\users\neha\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.22.2->qiskit-machine-learning) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\neha\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->qiskit-machine-learning) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\neha\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->qiskit-machine-learning) (1.1.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\neha\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra>=0.22.2->qiskit-machine-learning) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\neha\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.22.2->qiskit-machine-learning) (1.2.1)
# Building wheels for collected packages: fastdtw
#   Building wheel for fastdtw (setup.py): started
#   Building wheel for fastdtw (setup.py): finished with status 'done'
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-py3-none-any.whl size=3582 sha256=eb330f10d6000110f61633ed991bf6babb008f824d5b10f179268c3ab4ce50ac
#   Stored in directory: c:\users\neha\appdata\local\pip\cache\wheels\1f\a1\63\bfd0fddb5bf0b59f564872e29272cee8a2de0cd745d88fede5
# Successfully built fastdtw
# Installing collected packages: fastdtw, qiskit-machine-learning
# Successfully installed fastdtw-0.3.4 qiskit-machine-learning-0.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import time
from qiskit_machine_learning.algorithms.classifiers import VQC

vqc = VQC(
    sampler=sampler,
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=optimizer,
    callback=callback_graph,
)

# clear objective value history
objective_func_vals = []

start = time.time()
vqc.fit(train_features, train_labels)
elapsed = time.time() - start

print(f"Training time: {round(elapsed)} seconds")
# Out:
# Training time: 21163 seconds

# %%
train_score_q4 = vqc.score(train_features, train_labels)
test_score_q4 = vqc.score(test_features, test_labels)

print(f"Quantum VQC on the training dataset: {train_score_q4:.2f}")
print(f"Quantum VQC on the test dataset:     {test_score_q4:.2f}")
# Out:
# Quantum VQC on the training dataset: 0.85
# Quantum VQC on the test dataset:     0.87
